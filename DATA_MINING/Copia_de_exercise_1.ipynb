# %% [markdown]
# <a href="https://colab.research.google.com/github/jimenami/master_ciencia_datos/blob/main/DATA_MINING/Copia_de_exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio: un poco de Pandas

# %%
# Pasos previos

import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/d-tomas/data-mining/main/datasets/metal_bands.csv')

# %% [markdown]
# **1.** Muestra por pantalla todos los datos de las 10 primeras bandas

# %%
data.head(10)

# %% [markdown]
# **2.** Muestra por pantalla el nombre de las 5 últimas bandas

# %%
data.tail(5)

# %% [markdown]
# **3.** Cambia el nombre de la segunda columna por 'fanáticos'

# %%
type(data.fans)

# %%
data['fanáticos'] = data['fans']
del data['fans']
data

# %% [markdown]
# **4.** Muestra el nombre, país de origen y el número de fans de las bandas que se formaron en 1980

# %%
data.loc[data["formed"] == "1980", ["band_name", "origin", "fanáticos"]]

# %% [markdown]
# **5.** Muestra las 20 bandas españolas más antiguas

# %%
españolas = data.loc[data["origin"]=="Spain"]
descenso = españolas.sort_values(by = "formed", ascending=True)
descenso.head(20)
